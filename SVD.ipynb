# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mat = plt.imread("albert-einstein.jpg")

# %%
mat
# Out:
# array([[ 63,  64,  65, ...,  25,  25,  25],
#        [ 60,  60,  60, ...,  24,  24,  24],
#        [ 62,  61,  61, ...,  24,  24,  23],
#        ...,
#        [ 24,  12,  13, ..., 112,  46,  45],
#        [ 24,  13,  14, ...,  89,  92,  38],
#        [ 17,  18,  18, ...,  59,  69,  47]], dtype=uint8)

# %%
mat.shape
# Out:
# (640, 480)

# %%
# SVD 
U, s, VT = LA.svd(mat)
# U, s, VT = LA.svd(mat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-148429b25ad6> in <module>
#       1 # SVD
# ----> 2 U, s, VT = LA.svd(mat)
#       3 # U, s, VT = LA.svd(mat)
#
# NameError: name 'LA' is not defined

# %%
Sigma = np.zeros((mat.shape[0], mat.shape[1]))
Sigma[:min(mat.shape[0], mat.shape[1]), :min(mat.shape[0], mat.shape[1])] = np.diag(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-835ee5ef6ef7> in <module>
# ----> 1 Sigma = np.zeros((mat.shape[0], mat.shape[1]))
#       2 Sigma[:min(mat.shape[0], mat.shape[1]), :min(mat.shape[0], mat.shape[1])] = np.diag(s)
#
# NameError: name 'np' is not defined

# %%
Sigma.shape
Sigma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-efafa58d895a> in <module>
# ----> 1 Sigma.shape
#       2 Sigma
#
# NameError: name 'Sigma' is not defined

# %%
# Reconstruction of the matrix using the first 30 singular values
k= 30 
mat_approx = U[:, :k] @ Sigma[:k, :k] @ VT[:k, :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d41074b010fb> in <module>
#       1 # Reconstruction of the matrix using the first 30 singular values
#       2 k= 30
# ----> 3 mat_approx = U[:, :k] @ Sigma[:k, :k] @ VT[:k, :]
#
# NameError: name 'U' is not defined

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,8))
plt.subplots_adjust(wspace=0.3, hspace=0.2)

ax1.imshow(mat, cmap='gray')
ax1.set_title("Original image")

ax2.imshow(mat_approx, cmap='gray')
ax2.set_title("Reconstructed image using the \n first {} singular values".format(k))
plt.show()

# %%
from sklearn.datasets import fetch_olivetti_faces
data = fetch_olivetti_faces()

# %%
imgs = data.images
print(imgs.shape)
# Out:
# (400, 64, 64)

# %%
fig, axes = plt.subplots(1, 5, figsize=(14, 8))
plt.subplots_adjust(wspace=0.4)

for i in range(0, 5):
    axes[i].imshow(imgs[i*40], cmap='gray')

plt.show()
