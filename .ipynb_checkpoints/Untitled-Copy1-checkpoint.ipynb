# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from numpy import nan

# %%
data = pd.read_csv("Telecom_customer churn.csv")
copy_data = data.copy()
copy_data_2 = data.copy()

# %%
copy_data_2
# Out:
#        rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0       23.9975    219.25       22.500   0.2475         0.00          0.0
# 1       57.4925    482.75       37.425   0.2475        22.75          9.1
# 2       16.9900     10.25       16.990   0.0000         0.00          0.0
# 3       38.0000      7.50       38.000   0.0000         0.00          0.0
# 4       55.2300    570.50       71.980   0.0000         0.00          0.0
# ...         ...       ...          ...      ...          ...          ...
# 99995       NaN       NaN          NaN      NaN          NaN          NaN
# 99996       NaN       NaN          NaN      NaN          NaN          NaN
# 99997       NaN       NaN          NaN      NaN          NaN          NaN
# 99998       NaN       NaN          NaN      NaN          NaN          NaN
# 99999       NaN       NaN          NaN      NaN          NaN          NaN
#
#        vceovr_Mean  datovr_Mean  roam_Mean  change_mou  ...  forgntvl  ethnic  \
# ...

# %%
data.describe()
# Out:
#            rev_Mean      mou_Mean   totmrc_Mean       da_Mean   ovrmou_Mean  \
# count  99643.000000  99643.000000  99643.000000  99643.000000  99643.000000
# mean      58.719985    513.559937     46.179136      0.888828     41.072247
# std       46.291677    525.168140     23.623489      2.177619     97.296150
# min       -6.167500      0.000000    -26.915000      0.000000      0.000000
# 25%       33.260000    150.750000     30.000000      0.000000      0.000000
# 50%       48.195000    355.500000     44.990000      0.247500      2.750000
# 75%       70.750000    703.000000     59.990000      0.990000     42.000000
# max     3843.262500  12206.750000    409.990000    159.390000   4320.750000
#
#         ovrrev_Mean   vceovr_Mean   datovr_Mean     roam_Mean    change_mou  \
# count  99643.000000  99643.000000  99643.000000  99643.000000  99109.000000
# mean      13.559560     13.295062      0.261318      1.286405    -13.933818
# ...

# %%
data.shape
data.rev_Mean.mean()
# Out:
# 58.7199848459021

# %%
count_missing_values = data.isnull().sum()
count_missing_values
# Out:
# rev_Mean        357
# mou_Mean        357
# totmrc_Mean     357
# da_Mean         357
# ovrmou_Mean     357
#                ...
# kid11_15       1732
# kid16_17       1732
# creditcd       1732
# eqpdays           1
# Customer_ID       0
# Length: 100, dtype: int64

# %%
def missing_values_table(df):
    
        mis_val = df.isnull().sum()
        
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        type_column = df.dtypes
        
        mis_val_table = pd.concat([mis_val, mis_val_percent, type_column], axis=1)
        
        mis_val_table_ren_columns = mis_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of Total Values', 2:'type_column'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[mis_val_table_ren_columns.iloc[:,1] != 0].sort_values('% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
minfo_about_dataset = missing_values_table(data)
# Out:
# Your selected dataframe has 100 columns.
# There are 43 columns that have missing values.

# %%
data.numbcars
data.numbcars.isnull().sum()
# Out:
# 49366

# %%
data.prizm_social_one.dtypes
data.prizm_social_one.head()
# df.loc[df.education == '9th', 'education'].count()
# Out:
# 0    S
# 1    U
# 2    S
# 3    T
# 4    U
# Name: prizm_social_one, dtype: object

# %%
# minfo_about_dataset.loc[minfo_about_dataset.Type == 'object']
minfo_about_dataset
# Out:
#                   Missing Values  % of Total Values type_column
# numbcars                   49366               49.4     float64
# dwllsize                   38308               38.3      object
# HHstatin                   37923               37.9      object
# ownrent                    33706               33.7      object
# dwlltype                   31909               31.9      object
# lor                        30190               30.2     float64
# income                     25436               25.4     float64
# adults                     23019               23.0     float64
# infobase                   22079               22.1      object
# hnd_webcap                 10189               10.2      object
# prizm_social_one            7388                7.4      object
# avg6mou                     2839                2.8     float64
# avg6rev                     2839                2.8     float64
# avg6qty                     2839                2.8     float64
# ...

# %%
minfo_about_dataset.shape
# Out:
# (43, 3)

# %%
# minfo_about_dataset.type_column[0]
dataset = minfo_about_dataset.copy()
dataset
for index, row in dataset.iterrows():
    if row['type_column'] != "object":        
        #print(row['Missing Values'],index, row['type_column'])
        # calculate mean
        mean_ =  data[index].mean()
        # copy_data[index] = copy_data[index].map({'nan': mean_})
        # copy_data_1[index].fillna(round(mean_))
        #print(copy_data_1[index])
        copy_data_2[index].fillna(mean_, inplace=True)
        
        # copy_data_1[index].replace(to_replace=dict('NaN'=mean_), inplace=True)

        #print( round(mean_) )
        # replace mean with nan 
        # return 
missing_values_table(copy_data_2)
# copy_data
#copy_data_2
# Out:
# Your selected dataframe has 100 columns.
# There are 18 columns that have missing values.
#                   Missing Values  % of Total Values type_column
# dwllsize                   38308               38.3      object
# HHstatin                   37923               37.9      object
# ownrent                    33706               33.7      object
# dwlltype                   31909               31.9      object
# infobase                   22079               22.1      object
# hnd_webcap                 10189               10.2      object
# prizm_social_one            7388                7.4      object
# marital                     1732                1.7      object
# ethnic                      1732                1.7      object
# kid0_2                      1732                1.7      object
# kid3_5                      1732                1.7      object
# kid6_10                     1732                1.7      object
# ...

# %%
#def replace_missing_value_with_mean(df):
# visulasiation 
# Overlay 2 histograms to compare them
def barplot(x_data, y_data, error_data = "", x_label="", y_label="", title=""):
    _, ax = plt.subplots()
    # Draw bars, position them in the center of the tick mark on the x-axis
    ax.bar(x_data, y_data, color = '#539caf', align = 'center')
    # Draw error bars to show standard deviation, set ls to 'none'
    # to remove line between points
    # ax.errorbar(x_data, y_data, yerr = error_data, color = '#297083', ls = 'none', lw = 2, capthick = 2)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)

# %%
# copy_data_2.dwllsize
# example : 
# index = pd.Index([3, 1, 2, 3, 4, np.nan])
# index.value_counts()
dwllsize = copy_data_2["dwllsize"].value_counts()

# %%
dwllsize
# Out:
# A    47205
# B     5205
# C     1497
# J     1430
# O     1172
# N     1000
# D      747
# K      661
# E      543
# L      512
# F      410
# M      375
# G      365
# H      302
# I      268
# Name: dwllsize, dtype: int64

# %%
print(dwllsize.index)
print(dwllsize.values)
# Out:
# Index(['A', 'B', 'C', 'J', 'O', 'N', 'D', 'K', 'E', 'L', 'F', 'M', 'G', 'H',
#        'I'],
#       dtype='object')
# [47205  5205  1497  1430  1172  1000   747   661   543   512   410   375
#    365   302   268]

# %%
barplot(dwllsize.index, dwllsize.values)

# %%
HHstatin = copy_data_2["HHstatin"].value_counts()

# %%
print(HHstatin.index)
print(HHstatin.values)

total_value = sum(HHstatin.values)
print( total_value )
# 37923 
print( copy_data_2.shape[0] - total_value )


barplot(dwllsize.index, dwllsize.values)
# Out:
# Index(['C', 'I', 'A', 'B', 'G', 'H'], dtype='object')
# [39124 12352  4666  3246  1766   923]
# 62077
# 37923

# %%
# calculate %

#'percentage': ['First value', 'Second value',...],         
data = {'key':  HHstatin.index,
        'value': HHstatin.values}

df = pd.DataFrame (data, columns = ['key','value'])
HHstatin.shape
# Out:
# (6,)

# %%
df
# Out:
#   key  value
# 0   C  39124
# 1   I  12352
# 2   A   4666
# 3   B   3246
# 4   G   1766
# 5   H    923

# %%
nb_missing = copy_data_2.shape[0] - total_value 
print(nb_missing)
per = []
value_to_replace = []
for key, row in df.iterrows():
    percentage = round((row['value'] * 100 ) / total_value)
    # print(df.key[])
    # print(percentage)
    # print("around ", round(percentage))
    per.append(percentage)
    # nombre to replace by current value 
    to_replace =  round((percentage * nb_missing) / 100 ) 
    value_to_replace.append(to_replace)
    # print(to_replace)
sum(value_to_replace)
# Out:
# 37923
# 37923.0

# %%
# add co
df['percentage'] = per
df['to_replace'] = value_to_replace
df
# Out:
#   key  value  percentage  to_replace
# 0   C  39124        63.0     23891.0
# 1   I  12352        20.0      7585.0
# 2   A   4666         8.0      3034.0
# 3   B   3246         5.0      1896.0
# 4   G   1766         3.0      1138.0
# 5   H    923         1.0       379.0

# %%
df_info = df.copy()
#random.choice(df.key)
df_info.loc[df_info['key']=='C']
df_info
# Out:
#   key  value  percentage  to_replace
# 0   C  39124        63.0     23891.0
# 1   I  12352        20.0      7585.0
# 2   A   4666         8.0      3034.0
# 3   B   3246         5.0      1896.0
# 4   G   1766         3.0      1138.0
# 5   H    923         1.0       379.0

# %%
#for value in copy_data_2['HHstatin']:
    #if value is np.nan: 
        #print(value.index)
keys = df.key
keys = keys.to_frame()
test_key = keys.copy()
random_key = random.choice(keys['key'])
a = 100 
for i, value in copy_data_2['HHstatin'].iteritems():
    
    if a == 0:
        break
    
    
    if value is np.nan and len(keys.key.value_counts()) > 0:
        print("Len : ===> ", len(keys.key.value_counts()))
        print("Random Key : ===> ", random_key)        
        curr_value = df_info.loc[df_info['key'] == str(random_key) ]['to_replace'].values[0]
        print("Curr value : ===> ", curr_value)
        if curr_value > 0:            
            #df_info.loc[df_info['key'] == random_key ]['to_replace'].values[0] =  curr_value - 1
            # df_info.set_value(random_key, 'to_replace', random_key)
            df_info.set_value( df_info.key == random_key, 'to_replace', curr_value - 1)            
        else:            
            keys = keys[keys.key != 'C']
            print("Key rest : ===> ", keys.value)
            
        random_key = random.choice(keys['key'])
        print('')
        a = a - 1 
        #replace value         
        ### copy_data_2.set_value(i, 'HHstatin', random_key)
        #copy_data_2.loc[ copy_data_2.index == i ]['HHstatin'] = random_key
        
        
         
        
copy_data_2.loc[ copy_data_2.index == 15 ]['HHstatin']
# Out:
# Len : ===>  6
# Random Key : ===>  A
# Curr value : ===>  3001.0
# Len : ===>  6
# Random Key : ===>  B
# Curr value : ===>  1869.0
# Len : ===>  6
# Random Key : ===>  G
# Curr value : ===>  1105.0
# Len : ===>  6
# Random Key : ===>  B
# Curr value : ===>  1868.0
# Len : ===>  6
# Random Key : ===>  I
# Curr value : ===>  7548.0
# Len : ===>  6
# Random Key : ===>  A
# Curr value : ===>  3000.0
# Len : ===>  6
# Random Key : ===>  C
# Curr value : ===>  23857.0
# Len : ===>  6
# Random Key : ===>  A
# Curr value : ===>  2999.0
# Len : ===>  6
# Random Key : ===>  H
# Curr value : ===>  343.0
# Len : ===>  6
# Random Key : ===>  B
# Curr value : ===>  1867.0
# Len : ===>  6
# Random Key : ===>  A
# Curr value : ===>  2998.0
# Len : ===>  6
# Random Key : ===>  I
# Curr value : ===>  7547.0
# Len : ===>  6
# Random Key : ===>  A
# Curr value : ===>  2997.0
# Len : ===>  6
# Random Key : ===>  C
# Curr value : ===>  23856.0
# Len : ===>  6
# Random Key : ===>  C
# ...

# %%
df_info
#keys = keys.drop('C' , level=2)
#keys = keys.drop('C',level=1)  # df.columns is zero-based pd.Index 

#print(keys)
# dd = df_info.copy() 
#df_info.set_value('C', 'to_replace', 23891-1)

#dd.set_value( dd.key == 'C', 'to_replace', 0)

#copy_data_2.loc[ 15 ]['HHstatin'] = 'ok'
#copy_data_2.set_value(15, 'HHstatin', nan)
# copy_data_2.loc[ 15 ]['HHstatin']
# copy_data_2.loc[ copy_data_2.index == 15 ]['HHstatin'].values[0]
#random_key = random.choice(keys)
#curr_value = df_info.loc[df_info['key'] == random_key ]['to_replace']
#print( curr_value )
#print( curr_value.values[0] )
# Out:
#   key  value  percentage  to_replace
# 0   C  39124        63.0     23891.0
# 1   I  12352        20.0      7585.0
# 2   A   4666         8.0      3034.0
# 3   B   3246         5.0      1896.0
# 4   G   1766         3.0      1138.0
# 5   H    923         1.0       379.0

# %%
s = pd.Series(data=np.arange(3), index=['A', 'B', 'C'])
s
# Out:
# A    0
# B    1
# C    2
# dtype: int64

# %%
s = s.drop(labels=['B', 'C'])
s
# Out:
# A    0
# dtype: int64
